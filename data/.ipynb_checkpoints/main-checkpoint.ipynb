# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_firm_employment_size = pd.read_csv('firm_employment_size.csv')
df_firm_statistics = pd.read_csv('firms_statistics.csv')
df_years_in_business = pd.read_csv('years_in_business.csv')
to_drop = [x for x in df_firm_employment_size if '_F' in x or '_S' in x]

# %% [markdown]
# # ETL Process
# We created a list -=>
# ` to_drop = [x for x in df_firm_employment_size if '_F' in x or '_S' in x]`
# and used it to find the colums we wanted to remove from each csv.

# %%
# df_firm_employment_size.drop(to_drop, inplace=True, axis=1)
# df_firm_statistics.drop(to_drop, inplace=True, axis=1)
# df_years_in_business.drop(to_drop, inplace=True, axis=1)

# %%
df_firm_employment_size
# Out:
#                            GEO_ID      GEO_ID_F                  NAME  \
# 0      Geographic identifier code  Geo Footnote  Geographic Area Name
# 1                       0100000US           NaN         United States
# 2                       0100000US           NaN         United States
# 3                       0100000US           NaN         United States
# 4                       0100000US           NaN         United States
# ...                           ...           ...                   ...
# 15307                   0100000US           NaN         United States
# 15308                   0100000US           NaN         United States
# 15309                   0100000US           NaN         United States
# 15310                   0100000US           NaN         United States
# 15311                   0100000US           NaN         United States
#
#              NAICS2017          NAICS2017_F            NAICS2017_LABEL  \
# 0      2017 NAICS code  2017 NAICS Footnote      Meaning of NAICS code
# 1                   00                  NaN      Total for all sectors
# 2                   00                  NaN      Total for all sectors
# 3                   00                  NaN      Total for all sectors
# 4                   00                  NaN      Total for all sectors
# ...                ...                  ...                        ...
# 15307               99                  NaN  Industries not classified
# 15308               99                  NaN  Industries not classified
# 15309               99                  NaN  Industries not classified
# 15310               99                  NaN  Industries not classified
# 15311               99                  NaN  Industries not classified
#
#             SEX            SEX_LABEL       ETH_GROUP  \
# 0      Sex code  Meaning of Sex code  Ethnicity code
# 1           001                Total             001
# 2           001                Total             001
# 3           001                Total             001
# 4           001                Total             001
# ...         ...                  ...             ...
# 15307       096         Classifiable             096
# 15308       098       Unclassifiable             098
# 15309       098       Unclassifiable             098
# 15310       098       Unclassifiable             098
# 15311       098       Unclassifiable             098
#
#                  ETH_GROUP_LABEL  ...                          PAYANN_F  \
# 0      Meaning of Ethnicity code  ...  Flag for Annual payroll ($1,000)
# 1                          Total  ...                               NaN
# 2                          Total  ...                               NaN
# 3                          Total  ...                               NaN
# 4                          Total  ...                               NaN
# ...                          ...  ...                               ...
# 15307               Classifiable  ...                                 S
# 15308             Unclassifiable  ...                                 D
# 15309             Unclassifiable  ...                                 S
# 15310             Unclassifiable  ...                                 D
# 15311             Unclassifiable  ...                                 D
#
#                                          FIRMPDEMP_S  \
# 0      Relative standard error of employer firms (%)
# 1                                                0.8
# 2                                                0.4
# 3                                                1.0
# 4                                                0.9
# ...                                              ...
# 15307                                              S
# 15308                                              D
# 15309                                              S
# 15310                                              D
# 15311                                              D
#
#                                            FIRMPDEMP_S_F  \
# 0      Flag for Relative standard error of employer f...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15307                                                  S
# 15308                                                  D
# 15309                                                  S
# 15310                                                  D
# 15311                                                  D
#
#                                               RCPPDEMP_S  \
# 0      Relative standard error of sales, value of shi...
# 1                                                    3.6
# 2                                                    1.1
# 3                                                    1.5
# 4                                                    2.5
# ...                                                  ...
# 15307                                                  S
# 15308                                                  D
# 15309                                                  S
# 15310                                                  D
# 15311                                                  D
#
#                                             RCPPDEMP_S_F  \
# 0      Flag for Relative standard error of sales, val...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15307                                                  S
# 15308                                                  D
# 15309                                                  S
# 15310                                                  D
# 15311                                                  D
#
#                                                    EMP_S  \
# 0      Relative standard error of number of employees...
# 1                                                    0.0
# 2                                                    0.6
# 3                                                    0.9
# 4                                                    1.0
# ...                                                  ...
# 15307                                                  S
# 15308                                                  D
# 15309                                                  S
# 15310                                                  D
# 15311                                                  D
#
#                                                  EMP_S_F  \
# 0      Flag for Relative standard error of number of ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15307                                                  S
# 15308                                                  D
# 15309                                                  S
# 15310                                                  D
# 15311                                                  D
#
#                                             PAYANN_S  \
# 0      Relative standard error of annual payroll (%)
# 1                                                2.4
# 2                                                1.3
# 3                                                1.1
# 4                                                1.6
# ...                                              ...
# 15307                                              S
# 15308                                              D
# 15309                                              S
# 15310                                              D
# 15311                                              D
#
#                                               PAYANN_S_F Unnamed: 33
# 0      Flag for Relative standard error of annual pay...         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 15307                                                  S         NaN
# 15308                                                  D         NaN
# 15309                                                  S         NaN
# 15310                                                  D         NaN
# 15311                                                  D         NaN
#
# [15312 rows x 34 columns]

# %%
df_firm_statistics
# Out:
#                           GEO_ID      GEO_ID_F                  NAME
# 0     Geographic identifier code  Geo Footnote  Geographic Area Name  \
# 1                      0100000US           NaN         United States
# 2                      0100000US           NaN         United States
# 3                      0100000US           NaN         United States
# 4                      0100000US           NaN         United States
# ...                          ...           ...                   ...
# 4257                   0100000US           NaN         United States
# 4258                   0100000US           NaN         United States
# 4259                   0100000US           NaN         United States
# 4260                   0100000US           NaN         United States
# 4261                   0100000US           NaN         United States
#
#             NAICS2017          NAICS2017_F            NAICS2017_LABEL
# 0     2017 NAICS code  2017 NAICS Footnote      Meaning of NAICS code  \
# 1                   0                  NaN      Total for all sectors
# 2                   0                  NaN      Total for all sectors
# 3                   0                  NaN      Total for all sectors
# 4                   0                  NaN      Total for all sectors
# ...               ...                  ...                        ...
# 4257               99                  NaN  Industries not classified
# 4258               99                  NaN  Industries not classified
# 4259               99                  NaN  Industries not classified
# 4260               99                  NaN  Industries not classified
# 4261               99                  NaN  Industries not classified
#
#            SEX            SEX_LABEL       ETH_GROUP
# 0     Sex code  Meaning of Sex code  Ethnicity code  \
# 1            1                Total               1
# 2            2               Female               1
# 3            3                 Male               1
# 4            4  Equally male/female               1
# ...        ...                  ...             ...
# 4257         1                Total               1
# 4258         1                Total               1
# 4259         1                Total               1
# 4260        96         Classifiable              96
# 4261        98       Unclassifiable              98
#
#                 ETH_GROUP_LABEL  ...                   PAYANN
# 0     Meaning of Ethnicity code  ...  Annual payroll ($1,000)  \
# 1                         Total  ...               7227585564
# 2                         Total  ...                418552132
# 3                         Total  ...               2248777697
# 4                         Total  ...                293311176
# ...                         ...  ...                      ...
# 4257                      Total  ...                    69225
# 4258                      Total  ...                        S
# 4259                      Total  ...                   671861
# 4260               Classifiable  ...                   855369
# 4261             Unclassifiable  ...                     4311
#
#                               PAYANN_F
# 0     Flag for Annual payroll ($1,000)  \
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 4257                               NaN
# 4258                                 S
# 4259                               NaN
# 4260                               NaN
# 4261                               NaN
#
#                                         FIRMPDEMP_S
# 0     Relative standard error of employer firms (%)  \
# 1                                                 0
# 2                                               0.5
# 3                                               0.2
# 4                                               0.6
# ...                                             ...
# 4257                                            6.8
# 4258                                              S
# 4259                                              1
# 4260                                            1.1
# 4261                                           40.2
#
#                                           FIRMPDEMP_S_F
# 0     Flag for Relative standard error of employer f...  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4257                                                NaN
# 4258                                                  S
# 4259                                                NaN
# 4260                                                NaN
# 4261                                                NaN
#
#                                              RCPPDEMP_S
# 0     Relative standard error of sales, value of shi...  \
# 1                                                   1.1
# 2                                                   2.9
# 3                                                   2.3
# 4                                                     4
# ...                                                 ...
# 4257                                                  S
# 4258                                                  S
# 4259                                                  S
# 4260                                                  S
# 4261                                                  S
#
#                                            RCPPDEMP_S_F
# 0     Flag for Relative standard error of sales, val...  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4257                                                  S
# 4258                                                  S
# 4259                                                  S
# 4260                                                  S
# 4261                                                  S
#
#                                                   EMP_S
# 0     Relative standard error of number of employees...  \
# 1                                                   0.4
# 2                                                   1.5
# 3                                                   0.7
# 4                                                   1.7
# ...                                                 ...
# 4257                                               12.5
# 4258                                                  S
# 4259                                               19.9
# 4260                                               17.2
# 4261                                               58.2
#
#                                                 EMP_S_F
# 0     Flag for Relative standard error of number of ...  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4257                                                NaN
# 4258                                                  S
# 4259                                                NaN
# 4260                                                NaN
# 4261                                                NaN
#
#                                            PAYANN_S
# 0     Relative standard error of annual payroll (%)  \
# 1                                               0.5
# 2                                               1.7
# 3                                               1.1
# 4                                                 2
# ...                                             ...
# 4257                                           12.3
# 4258                                              S
# 4259                                            3.9
# 4260                                            3.2
# 4261                                           47.8
#
#                                              PAYANN_S_F
# 0     Flag for Relative standard error of annual pay...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4257                                                NaN
# 4258                                                  S
# 4259                                                NaN
# 4260                                                NaN
# 4261                                                NaN
#
# [4262 rows x 31 columns]

# %%
df_years_in_business
# Out:
#                            GEO_ID      GEO_ID_F                  NAME
# 0      Geographic identifier code  Geo Footnote  Geographic Area Name  \
# 1                       0100000US           NaN         United States
# 2                       0100000US           NaN         United States
# 3                       0100000US           NaN         United States
# 4                       0100000US           NaN         United States
# ...                           ...           ...                   ...
# 11627                   0100000US           NaN         United States
# 11628                   0100000US           NaN         United States
# 11629                   0100000US           NaN         United States
# 11630                   0100000US           NaN         United States
# 11631                   0100000US           NaN         United States
#
#              NAICS2017          NAICS2017_F            NAICS2017_LABEL
# 0      2017 NAICS code  2017 NAICS Footnote      Meaning of NAICS code  \
# 1                   00                  NaN      Total for all sectors
# 2                   00                  NaN      Total for all sectors
# 3                   00                  NaN      Total for all sectors
# 4                   00                  NaN      Total for all sectors
# ...                ...                  ...                        ...
# 11627               99                  NaN  Industries not classified
# 11628               99                  NaN  Industries not classified
# 11629               99                  NaN  Industries not classified
# 11630               99                  NaN  Industries not classified
# 11631               99                  NaN  Industries not classified
#
#             SEX            SEX_LABEL       ETH_GROUP
# 0      Sex code  Meaning of Sex code  Ethnicity code  \
# 1           001                Total             001
# 2           001                Total             001
# 3           001                Total             001
# 4           001                Total             001
# ...         ...                  ...             ...
# 11627       096         Classifiable             096
# 11628       098       Unclassifiable             098
# 11629       098       Unclassifiable             098
# 11630       098       Unclassifiable             098
# 11631       098       Unclassifiable             098
#
#                  ETH_GROUP_LABEL  ...                          PAYANN_F
# 0      Meaning of Ethnicity code  ...  Flag for Annual payroll ($1,000)  \
# 1                          Total  ...                               NaN
# 2                          Total  ...                               NaN
# 3                          Total  ...                               NaN
# 4                          Total  ...                               NaN
# ...                          ...  ...                               ...
# 11627               Classifiable  ...                               NaN
# 11628             Unclassifiable  ...                                 S
# 11629             Unclassifiable  ...                                 D
# 11630             Unclassifiable  ...                                 S
# 11631             Unclassifiable  ...                                 D
#
#                                          FIRMPDEMP_S
# 0      Relative standard error of employer firms (%)  \
# 1                                                0.8
# 2                                                1.0
# 3                                                0.9
# 4                                                0.9
# ...                                              ...
# 11627                                            4.0
# 11628                                              S
# 11629                                              D
# 11630                                              S
# 11631                                              D
#
#                                            FIRMPDEMP_S_F
# 0      Flag for Relative standard error of employer f...  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11627                                                NaN
# 11628                                                  S
# 11629                                                  D
# 11630                                                  S
# 11631                                                  D
#
#                                               RCPPDEMP_S
# 0      Relative standard error of sales, value of shi...  \
# 1                                                    2.8
# 2                                                    3.7
# 3                                                    4.3
# 4                                                    3.9
# ...                                                  ...
# 11627                                                  S
# 11628                                                  S
# 11629                                                  D
# 11630                                                  S
# 11631                                                  D
#
#                                             RCPPDEMP_S_F
# 0      Flag for Relative standard error of sales, val...  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11627                                                  S
# 11628                                                  S
# 11629                                                  D
# 11630                                                  S
# 11631                                                  D
#
#                                                    EMP_S
# 0      Relative standard error of number of employees...  \
# 1                                                    2.4
# 2                                                    3.5
# 3                                                    2.1
# 4                                                    2.5
# ...                                                  ...
# 11627                                               24.1
# 11628                                                  S
# 11629                                                  D
# 11630                                                  S
# 11631                                                  D
#
#                                                  EMP_S_F
# 0      Flag for Relative standard error of number of ...  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11627                                                NaN
# 11628                                                  S
# 11629                                                  D
# 11630                                                  S
# 11631                                                  D
#
#                                             PAYANN_S
# 0      Relative standard error of annual payroll (%)  \
# 1                                                2.5
# 2                                                2.9
# 3                                                4.4
# 4                                                3.4
# ...                                              ...
# 11627                                            6.4
# 11628                                              S
# 11629                                              D
# 11630                                              S
# 11631                                              D
#
#                                               PAYANN_S_F Unnamed: 33
# 0      Flag for Relative standard error of annual pay...         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 11627                                                NaN         NaN
# 11628                                                  S         NaN
# 11629                                                  D         NaN
# 11630                                                  S         NaN
# 11631                                                  D         NaN
#
# [11632 rows x 34 columns]
